# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np

# plt.rcParams['figure.figsize'] = [5, 5]
plt.rcParams.update({'font.size': 15})

B = imread('../data/lion-gray.jpg')
# B = np.mean(A, -1)

plt.figure()
plt.imshow(B, cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 1999.5, 1332.5, -0.5)

# %%
Bt = np.fft.fft2(B)
Btsort = np.sort(np.abs(Bt.reshape(-1)))

for keep in (0.1, 0.01, 0.001, 0.0001):
	
	thresh = Btsort[int(np.floor((1 - keep) * len(Btsort)))]
	ind = np.abs(Bt) > thresh

	Btlow = Bt * ind
	Alow = np.fft.ifft2(Btlow).real

	plt.figure()
	plt.imshow(Alow, cmap = 'gray')
	plt.axis('off')
	plt.title(f'keep = {keep * 100}% | ratio = {1 / keep}x')
